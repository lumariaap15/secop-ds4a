# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/SECOP_Electronicos_Cleaned.csv')

# %%
df.shape
# Out:
# (1583873, 36)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Nombre Entidad', 'Departamento', 'Orden', 'Sector',
#        'Rama', 'Entidad Centralizada', 'Estado Contrato', 'Tipo de Contrato',
#        'Modalidad de Contratacion', 'Fecha de Inicio del Contrato',
#        'Fecha de Fin del Contrato', 'Fecha de Inicio de Ejecucion',
#        'Fecha de Fin de Ejecucion', 'Es Grupo', 'Es Pyme',
#        'Obligación Ambiental', 'Obligaciones Postconsumo',
#        'Valor del Contrato', 'Valor de pago adelantado', 'Valor Facturado',
#        'Valor Pendiente de Pago', 'Valor Pagado', 'Valor Amortizado',
#        'Valor Pendiente de Amortizacion', 'Valor Pendiente de Ejecucion',
#        'EsPostConflicto', 'Destino Gasto', 'Dias Adicionados', 'PGN', 'SGP',
#        'SGR', 'RP_AGR', 'RP_NO_AGR', 'RC', 'Delay'],
#       dtype='object')

# %%
df
# Out:
#          Unnamed: 0                                     Nombre Entidad  \
# 0                 0  INSTITUTO DE PATRIMONIO Y CULTURAL DE CARTAGEN...
# 1                 1                   DIRECCION GENERAL MARITIMA-DIMAR
# 2                 2                             MUNICIPIO DE TOCANCIPA
# 3                 3  DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDI...
# 4                 4  INSTITUTO DEPARTAMENTAL PARA LA RECREACION Y E...
# ...             ...                                                ...
# 1583868     1711827                              SENA REGIONAL CAQUETA
# 1583869     1711828             GOBERNACION DEL VALLE DEL CAUCA - DADI
# 1583870     1711829                 ALCALDIA MUNICIPIO DE DOSQUEBRADAS
# 1583871     1711831                       ALCALDIA MUNICIPIO DE CAJICA
# 1583872     1711832  SENA REGIONAL CUNDINAMARCA Grupo Administrativ...
#
#             Departamento        Orden                     Sector       Rama  \
# 0                Bolívar  Territorial                    Cultura  Ejecutivo
# 1           Bogotá, D.C.     Nacional                    defensa  Ejecutivo
# 2           Cundinamarca  Territorial     No aplica/No pertenece  Ejecutivo
# 3               Casanare     Nacional  Salud y Protección Social  Ejecutivo
# 4           Bogotá, D.C.  Territorial                   deportes  Ejecutivo
# ...                  ...          ...                        ...        ...
# 1583868          Caquetá     Nacional                    Trabajo  Ejecutivo
# 1583869  Valle del Cauca  Territorial           Servicio Público  Ejecutivo
# 1583870        Risaralda  Territorial           Servicio Público  Ejecutivo
# 1583871     Cundinamarca  Territorial           Servicio Público  Ejecutivo
# 1583872     Cundinamarca     Nacional                    Trabajo  Ejecutivo
#
#         Entidad Centralizada Estado Contrato         Tipo de Contrato  \
# 0            Descentralizada    En ejecución  Prestación de servicios
# 1               Centralizada          Activo  Prestación de servicios
# 2            Descentralizada    En ejecución  Prestación de servicios
# 3               Centralizada          Activo  Prestación de servicios
# 4            Descentralizada    En ejecución  Prestación de servicios
# ...                      ...             ...                      ...
# 1583868      Descentralizada    En ejecución  Prestación de servicios
# 1583869      Descentralizada    En ejecución  Prestación de servicios
# 1583870         Centralizada    En ejecución  Prestación de servicios
# 1583871         Centralizada      Modificado        DecreeLaw092/2017
# 1583872      Descentralizada    En ejecución  Prestación de servicios
#
#                            Modalidad de Contratacion  ... EsPostConflicto  \
# 0                               Contratación directa  ...              No
# 1                               Contratación directa  ...              No
# 2                               Contratación directa  ...              No
# 3                                     Mínima cuantía  ...              No
# 4                               Contratación directa  ...              No
# ...                                              ...  ...             ...
# 1583868                         Contratación directa  ...              No
# 1583869                         Contratación directa  ...              No
# 1583870                         Contratación directa  ...              No
# 1583871  Contratación régimen especial (con ofertas)  ...              No
# 1583872                         Contratación directa  ...              No
#
#           Destino Gasto Dias Adicionados PGN SGP SGR RP_AGR RP_NO_AGR  RC  \
# 0             Inversión                0   0   0   0      1         0   0
# 1        Funcionamiento                0   0   0   0      0         0   0
# 2             Inversión                0   0   0   0      1         0   0
# 3        Funcionamiento                0   0   0   0      0         0   0
# 4             Inversión                0   0   0   0      1         0   0
# ...                 ...              ...  ..  ..  ..    ...       ...  ..
# 1583868       Inversión                0   1   0   0      0         0   0
# 1583869       Inversión                0   0   0   0      1         0   0
# 1583870       Inversión                0   0   0   0      1         0   0
# 1583871       Inversión                0   0   0   0      1         0   0
# 1583872       Inversión                0   1   0   0      0         0   0
#
#          Delay
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 1583868      0
# 1583869      0
# 1583870      0
# 1583871      0
# 1583872      0
#
# [1583873 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1583873 entries, 0 to 1583872
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   Unnamed: 0                       1583873 non-null  int64
#  1   Nombre Entidad                   1583873 non-null  object
#  2   Departamento                     1583873 non-null  object
#  3   Orden                            1583873 non-null  object
#  4   Sector                           1583873 non-null  object
#  5   Rama                             1583873 non-null  object
#  6   Entidad Centralizada             1583873 non-null  object
#  7   Estado Contrato                  1583873 non-null  object
#  8   Tipo de Contrato                 1583873 non-null  object
#  9   Modalidad de Contratacion        1583873 non-null  object
#  10  Fecha de Inicio del Contrato     1583873 non-null  object
#  11  Fecha de Fin del Contrato        1583873 non-null  object
#  12  Fecha de Inicio de Ejecucion     366400 non-null   object
#  13  Fecha de Fin de Ejecucion        370887 non-null   object
#  14  Es Grupo                         1583873 non-null  object
#  15  Es Pyme                          1583873 non-null  object
#  16  Obligación Ambiental             1583873 non-null  object
#  17  Obligaciones Postconsumo         1583873 non-null  object
#  18  Valor del Contrato               1583873 non-null  int64
#  19  Valor de pago adelantado         1583873 non-null  int64
#  20  Valor Facturado                  1583873 non-null  int64
#  21  Valor Pendiente de Pago          1583873 non-null  int64
#  22  Valor Pagado                     1583873 non-null  int64
#  23  Valor Amortizado                 1583873 non-null  int64
#  24  Valor Pendiente de Amortizacion  1583873 non-null  int64
#  25  Valor Pendiente de Ejecucion     1583873 non-null  int64
#  26  EsPostConflicto                  1583873 non-null  object
#  27  Destino Gasto                    1583873 non-null  object
#  28  Dias Adicionados                 1583873 non-null  int64
#  29  PGN                              1583873 non-null  int64
#  30  SGP                              1583873 non-null  int64
#  31  SGR                              1583873 non-null  int64
#  32  RP_AGR                           1583873 non-null  int64
#  33  RP_NO_AGR                        1583873 non-null  int64
#  34  RC                               1583873 non-null  int64
#  35  Delay                            1583873 non-null  int64
# dtypes: int64(17), object(19)
# memory usage: 435.0+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                               0
# Nombre Entidad                           0
# Departamento                             0
# Orden                                    0
# Sector                                   0
# Rama                                     0
# Entidad Centralizada                     0
# Estado Contrato                          0
# Tipo de Contrato                         0
# Modalidad de Contratacion                0
# Fecha de Inicio del Contrato             0
# Fecha de Fin del Contrato                0
# Fecha de Inicio de Ejecucion       1217473
# Fecha de Fin de Ejecucion          1212986
# Es Grupo                                 0
# Es Pyme                                  0
# Obligación Ambiental                     0
# Obligaciones Postconsumo                 0
# Valor del Contrato                       0
# Valor de pago adelantado                 0
# Valor Facturado                          0
# Valor Pendiente de Pago                  0
# Valor Pagado                             0
# Valor Amortizado                         0
# Valor Pendiente de Amortizacion          0
# Valor Pendiente de Ejecucion             0
# EsPostConflicto                          0
# Destino Gasto                            0
# Dias Adicionados                         0
# PGN                                      0
# SGP                                      0
# SGR                                      0
# RP_AGR                                   0
# RP_NO_AGR                                0
# RC                                       0
# Delay                                    0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0  Valor del Contrato  Valor de pago adelantado  \
# count  1.583873e+06        1.583873e+06              1.583873e+06
# mean   8.559859e+05        1.839242e+10              5.874672e+05
# std    4.941215e+05        8.597944e+12              6.565006e+07
# min    0.000000e+00        0.000000e+00              0.000000e+00
# 25%    4.282390e+05        1.015000e+07              0.000000e+00
# 50%    8.559490e+05        2.081900e+07              0.000000e+00
# 75%    1.283830e+06        4.000000e+07              0.000000e+00
# max    1.711832e+06        7.277005e+15              5.266143e+10
#
#        Valor Facturado  Valor Pendiente de Pago  Valor Pagado  \
# count     1.583873e+06             1.583873e+06  1.583873e+06
# mean      2.771968e+07             1.384736e+08  2.117688e+07
# std       7.968137e+08             3.716862e+09  6.117674e+08
# min       0.000000e+00            -2.369879e+09  0.000000e+00
# 25%       0.000000e+00             3.172990e+06  0.000000e+00
# 50%       0.000000e+00             1.286400e+07  0.000000e+00
# 75%       1.350000e+07             3.000000e+07  8.246784e+06
# max       4.932959e+11             9.958675e+11  3.341390e+11
#
#        Valor Amortizado  Valor Pendiente de Amortizacion  \
# count      1.583873e+06                     1.583873e+06
# mean       4.143316e+04                     5.460340e+05
# std        8.211752e+06                     6.490976e+07
# min        0.000000e+00                    -1.188033e+09
# 25%        0.000000e+00                     0.000000e+00
# 50%        0.000000e+00                     0.000000e+00
# 75%        0.000000e+00                     0.000000e+00
# max        4.852993e+09                     5.266143e+10
#
#        Valor Pendiente de Ejecucion  Dias Adicionados           PGN  \
# count                  1.583873e+06      1.583873e+06  1.583873e+06
# mean                   1.459269e+08      9.675819e+00  1.823644e-01
# std                    3.884137e+09      3.665770e+01  3.861447e-01
# min                   -5.445000e+10      0.000000e+00  0.000000e+00
# 25%                    7.700000e+06      0.000000e+00  0.000000e+00
# 50%                    1.800000e+07      0.000000e+00  0.000000e+00
# 75%                    3.752425e+07      0.000000e+00  0.000000e+00
# max                    9.958675e+11      6.759000e+03  1.000000e+00
#
#                 SGP           SGR        RP_AGR     RP_NO_AGR            RC  \
# count  1.583873e+06  1.583873e+06  1.583873e+06  1.583873e+06  1.583873e+06
# mean   3.135416e-02  6.385613e-03  3.294608e-01  1.520008e-01  2.640995e-03
# std    1.742730e-01  7.965451e-02  4.700176e-01  3.590218e-01  5.132272e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#               Delay
# count  1.583873e+06
# mean   2.614616e-01
# std    6.665577e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    3.000000e+00

# %%
df["Delay"].value_counts()
# Out:
# 0    1344052
# 2     125035
# 1      90153
# 3      24633
# Name: Delay, dtype: int64

# %%
df.groupby("Delay").mean()
# Out:
#           Unnamed: 0  Valor del Contrato  Valor de pago adelantado  \
# Delay
# 0      856330.374422        2.131843e+10              4.817981e+05
# 1      853383.452631        3.125096e+08              1.322474e+06
# 2      854385.926453        2.209679e+08              1.262049e+06
# 3      854833.541753        1.714675e+10              2.389667e+05
#
#        Valor Facturado  Valor Pendiente de Pago  Valor Pagado  \
# Delay
# 0         2.367442e+07             1.293559e+08  1.798239e+07
# 1         7.298964e+07             2.509007e+08  6.036054e+07
# 2         4.238065e+07             1.630941e+08  3.024122e+07
# 3         8.342747e+06             9.952442e+07  6.062149e+06
#
#        Valor Amortizado  Valor Pendiente de Amortizacion  \
# Delay
# 0          39885.223617                     4.419129e+05
# 1          37523.508203                     1.284950e+06
# 2          68688.496069                     1.193361e+06
# 3           1856.305972                     2.371104e+05
#
#        Valor Pendiente de Ejecucion  Dias Adicionados       PGN       SGP  \
# Delay
# 0                      1.364525e+08          0.000000  0.187959  0.030660
# 1                      2.650459e+08         26.073065  0.191230  0.026344
# 2                      1.705973e+08         78.254305  0.134258  0.046451
# 3                      1.016976e+08        129.508221  0.088824  0.010920
#
#             SGR    RP_AGR  RP_NO_AGR        RC
# Delay
# 0      0.006418  0.326879   0.139844  0.002587
# 1      0.004293  0.270241   0.204086  0.002573
# 2      0.007478  0.436670   0.218995  0.003567
# 3      0.006739  0.142898   0.284659  0.001137

# %%
df.groupby("Dias Adicionados").mean()
# Out:
#                     Unnamed: 0  Valor del Contrato  Valor de pago adelantado  \
# Dias Adicionados
# 0                 8.563359e+05        2.150007e+10             479339.257204
# 1                 8.467582e+05        2.884008e+08             196337.546778
# 2                 8.517038e+05        1.505724e+08             351258.484796
# 3                 8.392024e+05        1.368969e+08             183743.526742
# 4                 8.518237e+05        1.598554e+08                  0.000000
# ...                        ...                 ...                       ...
# 3289              6.658420e+05        0.000000e+00                  0.000000
# 3648              1.351974e+06        4.060000e+06                  0.000000
# 3652              1.121362e+06        0.000000e+00                  0.000000
# 3836              1.206305e+06        1.648640e+08                  0.000000
# 6759              1.534745e+06        0.000000e+00                  0.000000
#
#                   Valor Facturado  Valor Pendiente de Pago  Valor Pagado  \
# Dias Adicionados
# 0                    2.356033e+07             1.290338e+08  1.789800e+07
# 1                    2.044537e+08             8.999372e+07  1.983616e+08
# 2                    8.911825e+07             7.288231e+07  7.768625e+07
# 3                    4.189749e+07             8.654703e+07  3.459861e+07
# 4                    8.544287e+07             8.204683e+07  7.781179e+07
# ...                           ...                      ...           ...
# 3289                 0.000000e+00             0.000000e+00  0.000000e+00
# 3648                 2.660000e+06             4.060000e+06  0.000000e+00
# 3652                 0.000000e+00             0.000000e+00  0.000000e+00
# 3836                 1.648640e+08             0.000000e+00  1.648640e+08
# 6759                 0.000000e+00             0.000000e+00  0.000000e+00
#
#                   Valor Amortizado  Valor Pendiente de Amortizacion  \
# Dias Adicionados
# 0                     39643.361277                    439695.895908
# 1                    134095.634096                     62241.912682
# 2                         0.000000                    351258.484796
# 3                         0.000000                    183743.526742
# 4                         0.000000                         0.000000
# ...                            ...                              ...
# 3289                      0.000000                         0.000000
# 3648                      0.000000                         0.000000
# 3652                      0.000000                         0.000000
# 3836                      0.000000                         0.000000
# 6759                      0.000000                         0.000000
#
#                   Valor Pendiente de Ejecucion       PGN       SGP       SGR  \
# Dias Adicionados
# 0                                 1.360945e+08  0.187576  0.030556  0.006468
# 1                                 1.078423e+08  0.208732  0.034096  0.004574
# 2                                 7.308846e+07  0.308090  0.025818  0.006311
# 3                                 1.013607e+08  0.392761  0.018909  0.002701
# 4                                 9.910729e+07  0.433810  0.018571  0.002857
# ...                                        ...       ...       ...       ...
# 3289                              0.000000e+00  0.000000  0.000000  0.000000
# 3648                              4.060000e+06  0.000000  0.000000  0.000000
# 3652                              0.000000e+00  0.000000  0.000000  0.000000
# 3836                              1.648640e+08  0.000000  0.000000  0.000000
# 6759                              0.000000e+00  0.000000  0.000000  0.000000
#
#                     RP_AGR  RP_NO_AGR        RC     Delay
# Dias Adicionados
# 0                 0.326381   0.139589  0.002574  0.018192
# 1                 0.332640   0.190021  0.002911  1.007069
# 2                 0.298336   0.146299  0.002295  1.014917
# 3                 0.265262   0.124257  0.001621  1.030254
# 4                 0.199524   0.109048  0.000476  1.054286
# ...                    ...        ...       ...       ...
# 3289              0.000000   0.000000  0.000000  3.000000
# 3648              0.000000   1.000000  0.000000  3.000000
# 3652              0.000000   0.000000  0.000000  3.000000
# 3836              0.000000   0.000000  1.000000  3.000000
# 6759              0.000000   0.000000  0.000000  3.000000
#
# [596 rows x 16 columns]

# %%
df_graphs=df.sample(100)

# %%
df_graphs.shape
# Out:
# (100, 36)

# %%
# Plot Sizes

g=sns.pairplot(df_graphs, vars=[ 'Valor del Contrato', 'Dias Adicionados', 'Delay'] , diag_kind="hist")
g.fig.set_size_inches(10,4)

# %%
#Nombre Entidad
plt.title("Orden Vs Delay")
sns.violinplot(y="Orden",x="Delay",data=df).set(ylabel="Orden",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Orden'), Text(0.5, 0, 'Delay')]

# %%
#Sector
plt.title("Sector Vs Delay")
sns.violinplot(y="Sector",x="Delay",data=df).set(ylabel="Sector",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Sector'), Text(0.5, 0, 'Delay')]

# %%
#Rama
plt.title("Rama Vs Delay")
sns.violinplot(y="Rama",x="Delay",data=df).set(ylabel="Rama",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Rama'), Text(0.5, 0, 'Delay')]

# %%
#Entidad Centralizada
plt.title("Entidad Centralizada Vs Delay")
sns.violinplot(y="Entidad Centralizada",x="Delay",data=df).set(ylabel="Entidad Centralizada",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Entidad Centralizada'), Text(0.5, 0, 'Delay')]

# %%
#Estado Contrato
plt.title("Estado Contrato Vs Delay")
sns.violinplot(y="Estado Contrato",x="Delay",data=df).set(ylabel="Estado Contrato",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Estado Contrato'), Text(0.5, 0, 'Delay')]

# %%
#Tipo de contrato
plt.title("Tipo de Contrato Vs Delay")
sns.violinplot(y="Tipo de Contrato",x="Delay",data=df).set(ylabel="Tipo de Contrato",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Tipo de Contrato'), Text(0.5, 0, 'Delay')]

# %%
#Modalidad Contratacion
plt.title("Modalidad de Contratacion Vs Delay")
sns.violinplot(y="Modalidad de Contratacion",x="Delay",data=df).set(ylabel="Modalidad de Contratacion",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Modalidad de Contratacion'), Text(0.5, 0, 'Delay')]

# %%
#Es Grupo
plt.title("Es Grupo Vs Delay")
sns.violinplot(y="Es Grupo",x="Delay",data=df).set(ylabel="Es Grupo",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Es Grupo'), Text(0.5, 0, 'Delay')]

# %%
#Es pyme
plt.title("Es Pyme Vs Delay")
sns.violinplot(y="Es Pyme",x="Delay",data=df).set(ylabel="Es Pyme",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Es Pyme'), Text(0.5, 0, 'Delay')]

# %%
#Obligación Ambiental
plt.title("Obligación Ambiental Vs Delay")
sns.violinplot(y="Obligación Ambiental",x="Delay",data=df).set(ylabel="Obligación Ambiental",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Obligación Ambiental'), Text(0.5, 0, 'Delay')]

# %%
#Obligaciones Postconsumo
plt.title("Obligaciones Postconsumo Vs Delay")
sns.violinplot(y="Obligaciones Postconsumo",x="Delay",data=df).set(ylabel="Obligaciones Postconsumo",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Obligaciones Postconsumo'), Text(0.5, 0, 'Delay')]

# %%
#Valor del Contrato
plt.title("Valor del Contrato Vs Delay")
sns.boxplot(y="Valor del Contrato",x="Delay",data=df).set(ylabel="Valor del Contrato",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Valor del Contrato'), Text(0.5, 0, 'Delay')]

# %%
#EsPostConflicto
plt.title("EsPostConflicto Vs Delay")
sns.violinplot(y="EsPostConflicto",x="Delay",data=df).set(ylabel="EsPostConflicto",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'EsPostConflicto'), Text(0.5, 0, 'Delay')]

# %%
#Destino Gasto
plt.title("Destino Gasto Vs Delay")
sns.violinplot(y="Destino Gasto",x="Delay",data=df).set(ylabel="Destino Gasto",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Destino Gasto'), Text(0.5, 0, 'Delay')]

# %%
#Dias Adicionados
plt.title("Dias Adicionados Vs Delay")
sns.boxplot(y="Dias Adicionados",x="Delay",data=df).set(ylabel="Dias Adicionados",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Dias Adicionados'), Text(0.5, 0, 'Delay')]

# %%
#PGN
plt.title("PGN Vs Delay")
sns.violinplot(y="PGN",x="Delay",data=df).set(ylabel="PGN",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'PGN'), Text(0.5, 0, 'Delay')]

# %%
#SGP
plt.title("SGP Vs Delay")
sns.violinplot(y="SGP",x="Delay",data=df).set(ylabel="SGP",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'SGP'), Text(0.5, 0, 'Delay')]

# %%
#RP_AGR
plt.title("RP_AGR Vs Delay")
sns.violinplot(y="RP_AGR",x="Delay",data=df).set(ylabel="RP_AGR",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'RP_AGR'), Text(0.5, 0, 'Delay')]

# %%
#RP_NO_AGR
plt.title("RP_NO_AGR Vs Delay")
sns.violinplot(y="RP_NO_AGR",x="Delay",data=df).set(ylabel="RP_NO_AGR",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'RP_NO_AGR'), Text(0.5, 0, 'Delay')]

# %%
#RC
plt.title("RC Vs Delay")
sns.violinplot(y="RC",x="Delay",data=df).set(ylabel="RC",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'RC'), Text(0.5, 0, 'Delay')]

# %%
df_delay_difcero = df[df['Delay']!=0]
df_delay_difcero
# Out:
#          Unnamed: 0                                     Nombre Entidad  \
# 17               18  Secretaria Distrital de Integración Social - O...
# 18               19               SECRETARIA DE EDUCACION DEL DISTRITO
# 24               25                    MUNICIPIO DE SAN JOSE DE CUCUTA
# 34               36  UNIDAD ADMINISTRATIVA ESPECIAL DE GESTION DE R...
# 38               41  Rama Judicial  Dirección Seccional de Adminis...
# ...             ...                                                ...
# 1583851     1711809             CONTRALORIA DEPARTAMENTAL DEL GUAVIARE
# 1583855     1711813  CONGRESO DE LA REPÚBLICA - HONORABLE SENADO DE...
# 1583856     1711814  INSTITUTO DISTRITAL PARA LA PROTECCIÓN DE LA N...
# 1583859     1711817  UNIDAD DE SERVICIOS PENITENCIARIOS Y CARCELARI...
# 1583866     1711825  INSTITUCIÓN UNIVERSITARIA COLEGIO MAYOR DE ANT...
#
#                Departamento        Orden                             Sector  \
# 17             Bogotá, D.C.  Territorial  Inclusión Social y Reconciliación
# 18             Bogotá, D.C.  Territorial                 Educación Nacional
# 24       Norte de Santander  Territorial                   Servicio Público
# 34             Bogotá, D.C.     Nacional  Inclusión Social y Reconciliación
# 38                  Bolívar     Nacional                    Ley de Justicia
# ...                     ...          ...                                ...
# 1583851            Guaviare  Territorial             No aplica/No pertenece
# 1583855        Bogotá, D.C.     Nacional             No aplica/No pertenece
# 1583856        Bogotá, D.C.  Territorial          Salud y Protección Social
# 1583859        Bogotá, D.C.     Nacional                    Ley de Justicia
# 1583866           Antioquia  Territorial                 Educación Nacional
#
#                          Rama Entidad Centralizada Estado Contrato  \
# 17                  Ejecutivo         Centralizada      Modificado
# 18                  Ejecutivo         Centralizada      Modificado
# 24                  Ejecutivo         Centralizada      Modificado
# 34                  Ejecutivo         Centralizada      Modificado
# 38                   Judicial      Descentralizada          Activo
# ...                       ...                  ...             ...
# 1583851  Corporación Autónoma         Centralizada      Modificado
# 1583855           Legislativo         Centralizada      Modificado
# 1583856             Ejecutivo      Descentralizada      Modificado
# 1583859             Ejecutivo      Descentralizada      Modificado
# 1583866             Ejecutivo      Descentralizada      Modificado
#
#                 Tipo de Contrato Modalidad de Contratacion  ...  \
# 17       Prestación de servicios        Licitación pública  ...
# 18       Prestación de servicios      Contratación directa  ...
# 24       Prestación de servicios      Contratación directa  ...
# 34       Prestación de servicios      Contratación directa  ...
# 38                   Compraventa            Mínima cuantía  ...
# ...                          ...                       ...  ...
# 1583851  Prestación de servicios      Contratación directa  ...
# 1583855  Prestación de servicios      Contratación directa  ...
# 1583856  Prestación de servicios      Contratación directa  ...
# 1583859  Prestación de servicios      Contratación directa  ...
# 1583866  Prestación de servicios      Contratación directa  ...
#
#         EsPostConflicto   Destino Gasto Dias Adicionados PGN SGP SGR RP_AGR  \
# 17                   No  Funcionamiento               46   0   0   0      0
# 18                   No       Inversión               59   0   0   0      0
# 24                   No       Inversión               20   0   1   0      0
# 34                   No       Inversión               31   1   0   0      0
# 38                   No  Funcionamiento                9   0   0   0      0
# ...                 ...             ...              ...  ..  ..  ..    ...
# 1583851              No  Funcionamiento               41   0   0   0      1
# 1583855              No  Funcionamiento               49   0   0   0      0
# 1583856              No       Inversión               77   0   0   0      1
# 1583859              No  Funcionamiento               13   1   0   0      0
# 1583866              No  Funcionamiento               23   0   0   0      1
#
#         RP_NO_AGR  RC  Delay
# 17              0   0      1
# 18              1   0      2
# 24              0   0      1
# 34              0   0      2
# 38              0   0      2
# ...           ...  ..    ...
# 1583851         0   0      2
# 1583855         0   0      2
# 1583856         0   0      2
# 1583859         0   0      1
# 1583866         0   0      1
#
# [239821 rows x 36 columns]

# %%
#Nombre Entidad
plt.title("Orden Vs Delay")
sns.violinplot(y="Orden",x="Delay",data=df_delay_difcero).set(ylabel="Orden",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Orden'), Text(0.5, 0, 'Delay')]

# %%
#Sector
plt.title("Sector Vs Delay")
sns.violinplot(y="Sector",x="Delay",data=df_delay_difcero).set(ylabel="Sector",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Sector'), Text(0.5, 0, 'Delay')]

# %%
#Rama
plt.title("Rama Vs Delay")
sns.violinplot(y="Rama",x="Delay",data=df_delay_difcero).set(ylabel="Rama",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Rama'), Text(0.5, 0, 'Delay')]

# %%
#Entidad Centralizada
plt.title("Entidad Centralizada Vs Delay")
sns.violinplot(y="Entidad Centralizada",x="Delay",data=df_delay_difcero).set(ylabel="Entidad Centralizada",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Entidad Centralizada'), Text(0.5, 0, 'Delay')]

# %%
#Estado Contrato
plt.title("Estado Contrato Vs Delay")
sns.violinplot(y="Estado Contrato",x="Delay",data=df_delay_difcero).set(ylabel="Estado Contrato",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Estado Contrato'), Text(0.5, 0, 'Delay')]

# %%
#Tipo de contrato
plt.title("Tipo de Contrato Vs Delay")
sns.violinplot(y="Tipo de Contrato",x="Delay",data=df_delay_difcero).set(ylabel="Tipo de Contrato",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Tipo de Contrato'), Text(0.5, 0, 'Delay')]

# %%
#Modalidad Contratacion
plt.title("Modalidad de Contratacion Vs Delay")
sns.violinplot(y="Modalidad de Contratacion",x="Delay",data=df_delay_difcero).set(ylabel="Modalidad de Contratacion",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Modalidad de Contratacion'), Text(0.5, 0, 'Delay')]

# %%
#Es Grupo
plt.title("Es Grupo Vs Delay")
sns.violinplot(y="Es Grupo",x="Delay",data=df_delay_difcero).set(ylabel="Es Grupo",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Es Grupo'), Text(0.5, 0, 'Delay')]

# %%
#Es pyme
plt.title("Es Pyme Vs Delay")
sns.violinplot(y="Es Pyme",x="Delay",data=df_delay_difcero).set(ylabel="Es Pyme",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Es Pyme'), Text(0.5, 0, 'Delay')]

# %%
#Obligación Ambiental
plt.title("Obligación Ambiental Vs Delay")
sns.violinplot(y="Obligación Ambiental",x="Delay",data=df_delay_difcero).set(ylabel="Obligación Ambiental",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Obligación Ambiental'), Text(0.5, 0, 'Delay')]

# %%
#Obligaciones Postconsumo
plt.title("Obligaciones Postconsumo Vs Delay")
sns.violinplot(y="Obligaciones Postconsumo",x="Delay",data=df_delay_difcero).set(ylabel="Obligaciones Postconsumo",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Obligaciones Postconsumo'), Text(0.5, 0, 'Delay')]

# %%
#Valor del Contrato
plt.title("Valor del Contrato Vs Delay")
sns.boxplot(y="Valor del Contrato",x="Delay",data=df_delay_difcero).set(ylabel="Valor del Contrato",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Valor del Contrato'), Text(0.5, 0, 'Delay')]

# %%
#EsPostConflicto
plt.title("EsPostConflicto Vs Delay")
sns.violinplot(y="EsPostConflicto",x="Delay",data=df_delay_difcero).set(ylabel="EsPostConflicto",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'EsPostConflicto'), Text(0.5, 0, 'Delay')]

# %%
#Destino Gasto
plt.title("Destino Gasto Vs Delay")
sns.violinplot(y="Destino Gasto",x="Delay",data=df_delay_difcero).set(ylabel="Destino Gasto",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Destino Gasto'), Text(0.5, 0, 'Delay')]

# %%
#Dias Adicionados
plt.title("Dias Adicionados Vs Delay")
sns.boxplot(y="Dias Adicionados",x="Delay",data=df_delay_difcero).set(ylabel="Dias Adicionados",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'Dias Adicionados'), Text(0.5, 0, 'Delay')]

# %%
#PGN
plt.title("PGN Vs Delay")
sns.violinplot(y="PGN",x="Delay",data=df_delay_difcero).set(ylabel="PGN",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'PGN'), Text(0.5, 0, 'Delay')]

# %%
#SGP
plt.title("SGP Vs Delay")
sns.violinplot(y="SGP",x="Delay",data=df_delay_difcero).set(ylabel="SGP",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'SGP'), Text(0.5, 0, 'Delay')]

# %%
#RP_AGR
plt.title("RP_AGR Vs Delay")
sns.violinplot(y="RP_AGR",x="Delay",data=df_delay_difcero).set(ylabel="RP_AGR",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'RP_AGR'), Text(0.5, 0, 'Delay')]

# %%
#RP_NO_AGR
plt.title("RP_NO_AGR Vs Delay")
sns.violinplot(y="RP_NO_AGR",x="Delay",data=df_delay_difcero).set(ylabel="RP_NO_AGR",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'RP_NO_AGR'), Text(0.5, 0, 'Delay')]

# %%
#RC
plt.title("RC Vs Delay")
sns.violinplot(y="RC",x="Delay",data=df_delay_difcero).set(ylabel="RC",xlabel="Delay")
# Out:
# [Text(0, 0.5, 'RC'), Text(0.5, 0, 'Delay')]

# %%
sns.displot(x="Orden", data=df)

# %%
sns.displot(x="Sector", data=df)

# %%
sns.displot(x="Rama", data=df)

# %%
sns.displot(x="Entidad Centralizada", data=df)

# %%
sns.displot(x="Estado Contrato", data=df)

# %%
df_dias_difcero = df[df['Dias Adicionados']>0]
df_dias_difcero
# Out:
#          Unnamed: 0                                     Nombre Entidad  \
# 17               18  Secretaria Distrital de Integración Social - O...
# 18               19               SECRETARIA DE EDUCACION DEL DISTRITO
# 24               25                    MUNICIPIO DE SAN JOSE DE CUCUTA
# 34               36  UNIDAD ADMINISTRATIVA ESPECIAL DE GESTION DE R...
# 38               41  Rama Judicial  Dirección Seccional de Adminis...
# ...             ...                                                ...
# 1583851     1711809             CONTRALORIA DEPARTAMENTAL DEL GUAVIARE
# 1583855     1711813  CONGRESO DE LA REPÚBLICA - HONORABLE SENADO DE...
# 1583856     1711814  INSTITUTO DISTRITAL PARA LA PROTECCIÓN DE LA N...
# 1583859     1711817  UNIDAD DE SERVICIOS PENITENCIARIOS Y CARCELARI...
# 1583866     1711825  INSTITUCIÓN UNIVERSITARIA COLEGIO MAYOR DE ANT...
#
#                Departamento        Orden                             Sector  \
# 17             Bogotá, D.C.  Territorial  Inclusión Social y Reconciliación
# 18             Bogotá, D.C.  Territorial                 Educación Nacional
# 24       Norte de Santander  Territorial                   Servicio Público
# 34             Bogotá, D.C.     Nacional  Inclusión Social y Reconciliación
# 38                  Bolívar     Nacional                    Ley de Justicia
# ...                     ...          ...                                ...
# 1583851            Guaviare  Territorial             No aplica/No pertenece
# 1583855        Bogotá, D.C.     Nacional             No aplica/No pertenece
# 1583856        Bogotá, D.C.  Territorial          Salud y Protección Social
# 1583859        Bogotá, D.C.     Nacional                    Ley de Justicia
# 1583866           Antioquia  Territorial                 Educación Nacional
#
#                          Rama Entidad Centralizada Estado Contrato  \
# 17                  Ejecutivo         Centralizada      Modificado
# 18                  Ejecutivo         Centralizada      Modificado
# 24                  Ejecutivo         Centralizada      Modificado
# 34                  Ejecutivo         Centralizada      Modificado
# 38                   Judicial      Descentralizada          Activo
# ...                       ...                  ...             ...
# 1583851  Corporación Autónoma         Centralizada      Modificado
# 1583855           Legislativo         Centralizada      Modificado
# 1583856             Ejecutivo      Descentralizada      Modificado
# 1583859             Ejecutivo      Descentralizada      Modificado
# 1583866             Ejecutivo      Descentralizada      Modificado
#
#                 Tipo de Contrato Modalidad de Contratacion  ...  \
# 17       Prestación de servicios        Licitación pública  ...
# 18       Prestación de servicios      Contratación directa  ...
# 24       Prestación de servicios      Contratación directa  ...
# 34       Prestación de servicios      Contratación directa  ...
# 38                   Compraventa            Mínima cuantía  ...
# ...                          ...                       ...  ...
# 1583851  Prestación de servicios      Contratación directa  ...
# 1583855  Prestación de servicios      Contratación directa  ...
# 1583856  Prestación de servicios      Contratación directa  ...
# 1583859  Prestación de servicios      Contratación directa  ...
# 1583866  Prestación de servicios      Contratación directa  ...
#
#         EsPostConflicto   Destino Gasto Dias Adicionados PGN SGP SGR RP_AGR  \
# 17                   No  Funcionamiento               46   0   0   0      0
# 18                   No       Inversión               59   0   0   0      0
# 24                   No       Inversión               20   0   1   0      0
# 34                   No       Inversión               31   1   0   0      0
# 38                   No  Funcionamiento                9   0   0   0      0
# ...                 ...             ...              ...  ..  ..  ..    ...
# 1583851              No  Funcionamiento               41   0   0   0      1
# 1583855              No  Funcionamiento               49   0   0   0      0
# 1583856              No       Inversión               77   0   0   0      1
# 1583859              No  Funcionamiento               13   1   0   0      0
# 1583866              No  Funcionamiento               23   0   0   0      1
#
#         RP_NO_AGR  RC  Delay
# 17              0   0      1
# 18              1   0      2
# 24              0   0      1
# 34              0   0      2
# 38              0   0      2
# ...           ...  ..    ...
# 1583851         0   0      2
# 1583855         0   0      2
# 1583856         0   0      2
# 1583859         0   0      1
# 1583866         0   0      1
#
# [231621 rows x 36 columns]

# %%
sns.scatterplot(x="Valor del Contrato", y="Dias Adicionados" ,data=df_dias_difcero , hue="Delay")
# Out:
# <AxesSubplot:xlabel='Valor del Contrato', ylabel='Dias Adicionados'>

# %%
g=sns.pairplot(df_graphs, vars=[ 'Valor del Contrato', 'Valor Facturado',
       'Valor Pendiente de Pago', 'Valor Pagado', 'Valor Pendiente de Ejecucion','Dias Adicionados'] , diag_kind="hist")
g.fig.set_size_inches(25,25)

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("www.datos.gov.co", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(www.datos.gov.co,
#                  PJuW5IP16J0AUyEyOmWF5iTYr,
#                  userame="lumariaap15@gmail.com",
#                  password="Lmap2019*")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("jbjy-vk9h", limit=1000000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("jbjy-vk9h", limit=1000000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/luisaalzate/Desktop/secop/ejemplo_con_pandas.ipynb Cell 2' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/luisaalzate/Desktop/secop/ejemplo_con_pandas.ipynb#ch0000003?line=0'>1</a> results = client.get("jbjy-vk9h", limit=1000000)
#       <a href='vscode-notebook-cell:/Users/luisaalzate/Desktop/secop/ejemplo_con_pandas.ipynb#ch0000003?line=2'>3</a> # Convert to pandas DataFrame
# ----> <a href='vscode-notebook-cell:/Users/luisaalzate/Desktop/secop/ejemplo_con_pandas.ipynb#ch0000003?line=3'>4</a> results_df = pd.DataFrame.from_records(results)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:1895, in DataFrame.from_records(cls, data, index, exclude, columns, coerce_float, nrows)
#    1892     arr_columns = arr_columns.drop(arr_exclude)
#    1893     columns = columns.drop(exclude)
# ...

# %%
#authenticated

client2 = Socrata("www.datos.gov.co",
                  "PJuW5IP16J0AUyEyOmWF5iTYr",
                  userame="lumariaap15@gmail.com",
                  password="Lmap2019*")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results2 = client2.get("jbjy-vk9h", limit=1000000)

# Convert to pandas DataFrame
results_df2 = pd.DataFrame.from_records(results2)

# %%
results_df.head()
# Out:
#                                       nombre_entidad nit_entidad  \
# 0  INSTITUTO DE PATRIMONIO Y CULTURAL DE CARTAGEN...   806013631
# 1                   DIRECCION GENERAL MARITIMA-DIMAR   830027904
# 2                             MUNICIPIO DE TOCANCIPA   899999428
# 3  DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDI...   901540945
# 4  INSTITUTO DEPARTAMENTAL PARA LA RECREACION Y E...   900294884
#
#                  departamento       ciudad  \
# 0                     Bolívar    Cartagena
# 1  Distrito Capital de Bogotá  No Definido
# 2                Cundinamarca    Tocancipá
# 3                    Casanare        Yopal
# 4  Distrito Capital de Bogotá  No Definido
#
#                            localizaci_n        orden  \
# 0       Colombia,  Bolívar ,  Cartagena  Territorial
# 1              Colombia, Bogotá, Bogotá     Nacional
# 2  Colombia,  Cundinamarca ,  Tocancipá  Territorial
# 3          Colombia,  Casanare ,  Yopal     Nacional
# ...
